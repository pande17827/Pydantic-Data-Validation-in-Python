# %% [markdown]
# # <b>Serialization

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from pydantic import BaseModel

class User(BaseModel):
    name: str
    age: int

user = User(name="Alice", age=30)

print(user.model_dump())  # ➝ {'name': 'Alice', 'age': 30}
print(type(user.model_dump()))
# Out:
# {'name': 'Alice', 'age': 30}
# <class 'dict'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
from pydantic import BaseModel

class User(BaseModel):
    name: str
    age: int

user = User(name="Alice", age=30)

print(user.model_dump_json())  # ➝ {'name': 'Alice', 'age': 30}
print(type(user.model_dump_json()))
# Out:
# {"name":"Alice","age":30}
# <class 'str'>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![FancyGPT - 1748159978728.jpg](data:image/jpeg;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)
